# %%
import pandas as pd
import datetime
from os.path import exists


path_d = "../data-raw/ETHZ DEU/"
path_a = "../data-raw/ETHZ AUT/"
path_c = "../data-raw/ETHZ CHE/"

date_range = pd.date_range("2020-08-17", datetime.date.today())

for date1 in date_range:
    date = str(date1)[0:10]
    output_dataframe1 = pd.DataFrame()
    output_dataframe2 = pd.DataFrame()
    output_dataframe3 = pd.DataFrame()
    output_dataframe4 = pd.DataFrame()

    file_found = False

    if exists(path_d + str(date) + "_ethz_deu_raw.csv"):
        file_found = True
        input_cc = pd.read_csv(path_d + str(date) + "_ethz_deu_raw.csv")
        input_deaths = input_cc[input_cc['data_type'] == 'Deaths']
        input_cc = input_cc[input_cc['data_type'] == 'Confirmed cases']

        df1 = input_cc[input_cc['estimate_type'] == 'Cori_slidingWindow']
        df2 = input_cc[input_cc['estimate_type'] == 'Cori_step']
        df3 = input_deaths[input_deaths['estimate_type'] == 'Cori_slidingWindow']
        df4 = input_deaths[input_deaths['estimate_type'] == 'Cori_step']



        for i in range(0, len(df1)):
            output_dataframe1 = output_dataframe1.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df1.iloc[i, 5], df1.iloc[i, 5], df1.iloc[i, 5]], 'location': ["DE", "DE", "DE"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df1.iloc[i, 6], df1.iloc[i, 8], df1.iloc[i, 7]]}))

        for i in range(0, len(df2)):
            output_dataframe2 = output_dataframe2.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df2.iloc[i, 5], df2.iloc[i, 5], df2.iloc[i, 5]], 'location': ["DE", "DE", "DE"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df2.iloc[i, 6], df2.iloc[i, 8], df2.iloc[i, 7]]}))

        for i in range(0, len(df3)):
            output_dataframe3 = output_dataframe3.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df3.iloc[i, 5], df3.iloc[i, 5], df3.iloc[i, 5]], 'location': ["DE", "DE", "DE"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df3.iloc[i, 6], df3.iloc[i, 8], df3.iloc[i, 7]]}))

        for i in range(0, len(df4)):
            output_dataframe4 = output_dataframe4.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df4.iloc[i, 5], df4.iloc[i, 5], df4.iloc[i, 5]], 'location': ["DE", "DE", "DE"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df4.iloc[i, 6], df4.iloc[i, 8], df4.iloc[i, 7]]}))

    # if corresponding file from Austria exists, append it:
    if exists(path_a + str(date) + "_ethz_aut_raw.csv"):
        file_found = True
        input_cc = pd.read_csv(path_a + str(date) + "_ethz_aut_raw.csv")
        input_deaths = input_cc[input_cc['data_type'] == 'Deaths']
        input_cc = input_cc[input_cc['data_type'] == 'Confirmed cases']

        df1 = input_cc[input_cc['estimate_type'] == 'Cori_slidingWindow']
        df2 = input_cc[input_cc['estimate_type'] == 'Cori_step']
        df3 = input_deaths[input_deaths['estimate_type'] == 'Cori_slidingWindow']
        df4 = input_deaths[input_deaths['estimate_type'] == 'Cori_step']

        for i in range(0, len(df1)):
            output_dataframe1 = output_dataframe1.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df1.iloc[i, 5], df1.iloc[i, 5], df1.iloc[i, 5]], 'location': ["AT", "AT", "AT"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df1.iloc[i, 6], df1.iloc[i, 8], df1.iloc[i, 7]]}))

        for i in range(0, len(df2)):
            output_dataframe2 = output_dataframe2.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df2.iloc[i, 5], df2.iloc[i, 5], df2.iloc[i, 5]], 'location': ["AT", "AT", "AT"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df2.iloc[i, 6], df2.iloc[i, 8], df2.iloc[i, 7]]}))

        for i in range(0, len(df3)):
            output_dataframe3 = output_dataframe3.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df3.iloc[i, 5], df3.iloc[i, 5], df3.iloc[i, 5]], 'location': ["AT", "AT", "AT"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df3.iloc[i, 6], df3.iloc[i, 8], df3.iloc[i, 7]]}))

        for i in range(0, len(df4)):
            output_dataframe4 = output_dataframe4.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df4.iloc[i, 5], df4.iloc[i, 5], df4.iloc[i, 5]], 'location': ["AT", "AT", "AT"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df4.iloc[i, 6], df4.iloc[i, 8], df4.iloc[i, 7]]}))

    # if corresponding file from Switzerland exists, append it:
    if exists(path_c + str(date) + "_ethz_che_raw.csv"):
        file_found = True
        input_cc = pd.read_csv(path_c + str(date) + "_ethz_che_raw.csv")
        input_cc = input_cc[input_cc['region'] == 'CHE']
        input_deaths = input_cc[input_cc['data_type'] == 'Deaths']
        input_cc = input_cc[input_cc['data_type'] == 'Confirmed cases']

        df1 = input_cc[input_cc['estimate_type'] == 'Cori_slidingWindow']
        df2 = input_cc[input_cc['estimate_type'] == 'Cori_step']
        df3 = input_deaths[input_deaths['estimate_type'] == 'Cori_slidingWindow']
        df4 = input_deaths[input_deaths['estimate_type'] == 'Cori_step']

        for i in range(0, len(df1)):
            output_dataframe1 = output_dataframe1.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df1.iloc[i, 5], df1.iloc[i, 5], df1.iloc[i, 5]], 'location': ["CH", "CH", "CH"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df1.iloc[i, 6], df1.iloc[i, 8], df1.iloc[i, 7]]}))

        for i in range(0, len(df2)):
            output_dataframe2 = output_dataframe2.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df2.iloc[i, 5], df2.iloc[i, 5], df2.iloc[i, 5]], 'location': ["CH", "CH", "CH"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df2.iloc[i, 6], df2.iloc[i, 8], df2.iloc[i, 7]]}))

        for i in range(0, len(df3)):
            output_dataframe3 = output_dataframe3.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df3.iloc[i, 5], df3.iloc[i, 5], df3.iloc[i, 5]], 'location': ["CH", "CH", "CH"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df3.iloc[i, 6], df3.iloc[i, 8], df3.iloc[i, 7]]}))

        for i in range(0, len(df4)):
            output_dataframe4 = output_dataframe4.append(pd.DataFrame({'data_version': [str(date), str(date), str(date)], 'target': ["3 day R", "3 day R", "3 day R"], 'date': [df4.iloc[i, 5], df4.iloc[i, 5], df4.iloc[i, 5]], 'location': ["CH", "CH", "CH"], 'type': ["point", "quantile", "quantile"], 'quantile': ["NA", "0.025", "0.975"], 'value': [df4.iloc[i, 6], df4.iloc[i, 8], df4.iloc[i, 7]]}))

    if file_found:
        output_dataframe1.to_csv("../data-processed/ETHZ_sliding_window/" + str(date) + "-ETHZ_sliding_window.csv", index=False, index_label=False)
        output_dataframe2.to_csv("../data-processed/ETHZ_step/" + str(date) + "-ETHZ_step.csv", index=False, index_label=False)
        output_dataframe3.to_csv("../data-processed/ETHZ_sliding_window_deaths/" + str(date) + "-ETHZ_sliding_window_deaths.csv", index=False, index_label=False)
        output_dataframe4.to_csv("../data-processed/ETHZ_step_deaths/" + str(date) + "-ETHZ_step_deaths.csv", index=False, index_label=False)
# Out:
# C:\Users\Jonas\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3155: DtypeWarning: Columns (0,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
